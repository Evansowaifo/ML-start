# 250  2020-01-07  1397.94  1402.99  1390.38  1393.34   1393.34  1502700
# 251  2020-01-08  1392.08  1411.58  1390.84  1404.32   1404.32  1528000
#
# [252 rows x 7 columns]

# %%
car.describe(include='all')
# Out:
#               Date    Open    High         Low        Close    Adj Close  \
# count          252   252.0   252.0   252.00000   252.000000   252.000000
# unique         252   249.0   250.0   251.00000   251.000000   251.000000
# top     2019-11-11  1350.0  1200.0  1111.01001  1343.560059  1343.560059
# freq             1     2.0     2.0     2.00000     2.000000     2.000000
#
#          Volume
# count       252
# unique      251
# top     1331800
# freq          2

# %%
car.hist(figsize=(20,30))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-8829d9c24ea3> in <module>
# ----> 1 car.hist(figsize=(20,30))
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     209     """
#     210     plot_backend = _get_plot_backend(backend)
# --> 211     return plot_backend.hist_frame(
#     212         data,
#     213         column=column,
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     413
#     414     if naxes == 0:
# --> 415         raise ValueError("hist method requires numerical columns, nothing to plot.")
#     416
# ...

# %%
car.shape
# Out:
# (252, 7)

# %%
duplicate_rows_car = car[car.duplicated()]
print("Number of duplicate rows: ", duplicate_rows_car.shape)
# Out:
# Number of duplicate rows:  (0, 7)

# %%
car = car.drop_duplicates()
car
# Out:
#            Date     Open     High      Low    Close Adj Close   Volume
# 0    2019-01-09  1081.65  1082.63   1066.4  1074.66   1074.66  1199300
# 1    2019-01-10  1067.66  1071.15  1057.71  1070.33   1070.33  1456400
# 2    2019-01-11  1063.18  1063.78  1048.48  1057.19   1057.19  1520800
# 3        Bishop   Bishop   Bishop   Bishop   Bishop    Bishop   Bishop
# 4    2019-01-15  1050.17  1080.05  1047.34  1077.15   1077.15  1463600
# ..          ...      ...      ...      ...      ...       ...      ...
# 247  2020-01-02  1341.55  1368.14  1341.55  1367.37   1367.37  1406600
# 248  2020-01-03  1347.86   1372.5  1345.54  1360.66   1360.66  1186400
# 249  2020-01-06     1350   1396.5     1350  1394.21   1394.21  1732300
# 250  2020-01-07  1397.94  1402.99  1390.38  1393.34   1393.34  1502700
# 251  2020-01-08  1392.08  1411.58  1390.84  1404.32   1404.32  1528000
#
# [252 rows x 7 columns]

# %%
car = car.drop(['Close'], axis=1)
car.head()
# Out:
#          Date     Open     High      Low Adj Close   Volume
# 0  2019-01-09  1081.65  1082.63   1066.4   1074.66  1199300
# 1  2019-01-10  1067.66  1071.15  1057.71   1070.33  1456400
# 2  2019-01-11  1063.18  1063.78  1048.48   1057.19  1520800
# 3      Bishop   Bishop   Bishop   Bishop    Bishop   Bishop
# 4  2019-01-15  1050.17  1080.05  1047.34   1077.15  1463600
